# %% [markdown]
# ## Training of feature extractor (head layer)

# %%
from datetime import datetime

import torch
import torch.backends.cudnn as cudnn
from torchvision import transforms, datasets

from models.model import ConvModel
from models.head_trainer import HeadTrainer

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    cudnn.deterministic = True
    cudnn.benchmark = True
    gpu_index = 0
else:
    device = torch.device('cpu')
    gpu_index = -1

# %%
model = ConvModel(out_dim=10, dataset='CIFAR10')

model.load_state_dict(torch.load('saved_models/pretraining/pretrained_cifar10.pth'))
# Out:
# C:\Users\kacpe\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\kacpe\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <All keys matched successfully>

# %%
g = torch.Generator()
g.manual_seed(0)

# %%
head_dataset = datasets.CIFAR10('./datasets', download=True, train=True, transform=transforms.ToTensor())
head_loader = torch.utils.data.DataLoader(head_dataset, batch_size=256, shuffle=True, pin_memory=True, drop_last=True, generator=g)
# Out:
# Files already downloaded and verified

# %%
model.backbone.fc = torch.nn.Sequential(
    torch.nn.Linear(in_features=512, out_features=128, bias=True),
    torch.nn.ReLU(inplace=True),
    torch.nn.BatchNorm1d(128),
    torch.nn.Linear(in_features=128, out_features=10, bias=True),
)
model.backbone.requires_grad_(False)
model.backbone.fc.requires_grad_(True)
# Out:
# Sequential(
#   (0): Linear(in_features=512, out_features=128, bias=True)
#   (1): ReLU(inplace=True)
#   (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), 0.0003, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=len(head_loader), eta_min=0,
                                                       last_epoch=-1)

# %%
with torch.cuda.device(gpu_index):
    simclr = HeadTrainer(model=model, optimizer=optimizer, scheduler=scheduler, device=device, epochs=400, log_every_n_steps=100,
                         log_dir=f'runs/Head_training_CIFAR10_{datetime.now().strftime("%d-%m-%Y_%H-%M")}')
    simclr.train(head_loader)
# Out:
#   0%|          | 0/195 [00:00<?, ?it/s]C:\Users\kacpe\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torch\optim\lr_scheduler.py:807: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# 100%|██████████| 195/195 [00:20<00:00,  9.74it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.02it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.20it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.13it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.25it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.13it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.83it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.75it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.91it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.91it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.73it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.86it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.87it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.72it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.27it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.39it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.09it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.02it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.68it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.36it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.83it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.78it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.81it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.94it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.72it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.09it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.86it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.18it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.35it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.86it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.70it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.71it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.69it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.01it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.53it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.68it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.68it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.41it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.39it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.02it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.69it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.54it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.10it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.26it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.50it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.68it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.55it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.24it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.94it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.20it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.88it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.08it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.39it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.47it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.15it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.27it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.19it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.18it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.31it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.49it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.87it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.70it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.05it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.21it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.62it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.80it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.35it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.72it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.71it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.50it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.43it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.29it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.44it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.55it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.51it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.65it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.83it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.65it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.43it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.99it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.07it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.32it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.81it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.30it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.53it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.89it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.74it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.40it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.92it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.12it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.59it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.46it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.72it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.32it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.03it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.08it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.63it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.08it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.15it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.47it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.95it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.68it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.55it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.97it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.74it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.00it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.96it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.28it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.94it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.97it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.43it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.25it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.14it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.16it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.34it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.94it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.55it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.90it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.89it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.73it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.80it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.34it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.42it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.47it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.67it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.00it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.11it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.72it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.02it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.39it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.08it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.30it/s]
# 100%|██████████| 195/195 [00:09<00:00, 21.32it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.78it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.60it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.34it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.28it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.83it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.67it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.35it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.90it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.03it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.13it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.74it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.02it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.58it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.12it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.94it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.08it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.78it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.90it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.71it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.44it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.21it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.80it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.95it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.49it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.05it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.30it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.54it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.74it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.02it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.60it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.80it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.11it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.64it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.48it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.54it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.73it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.67it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.95it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.69it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.53it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.53it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.81it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.70it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.28it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.60it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.13it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.21it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.26it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.35it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.59it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.66it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.71it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.73it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.97it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.51it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.35it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.62it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.50it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.27it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.84it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.07it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.37it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.36it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.40it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.71it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.40it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.65it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.60it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.56it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.19it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.51it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.62it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.66it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.38it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.71it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.06it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.70it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.39it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.85it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.27it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.38it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.11it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.36it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.51it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.06it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.74it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.73it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.73it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.46it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.05it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.33it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.66it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.49it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.49it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.57it/s]
# 100%|██████████| 195/195 [00:07<00:00, 24.97it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.43it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.81it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.04it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.16it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.99it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.10it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.90it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.32it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.01it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.07it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.96it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.16it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.63it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.94it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.04it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.83it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.12it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.28it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.40it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.61it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.43it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.20it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.52it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.88it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.21it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.54it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.01it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.56it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.21it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.14it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.56it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.47it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.89it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.09it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.78it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.50it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.89it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.65it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.56it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.51it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.11it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.77it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.59it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.57it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.98it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.54it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.88it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.14it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.27it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.68it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.48it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.40it/s]
# 100%|██████████| 195/195 [00:06<00:00, 28.01it/s]
# 100%|██████████| 195/195 [00:06<00:00, 27.97it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.82it/s]
# 100%|██████████| 195/195 [00:07<00:00, 27.44it/s]
# 100%|██████████| 195/195 [00:07<00:00, 26.66it/s]
# 100%|██████████| 195/195 [00:07<00:00, 25.90it/s]
#  37%|███▋      | 73/195 [00:02<00:04, 25.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 4
#       1 with torch.cuda.device(gpu_index):
#       2     simclr = HeadTrainer(model=model, optimizer=optimizer, scheduler=scheduler, device=device, epochs=400, log_every_n_steps=100,
#       3                          log_dir=f'runs/Head_training_CIFAR10_{datetime.now().strftime("%d-%m-%Y_%H-%M")}')
# ----> 4     simclr.train(head_loader)
#
# File ~\DataspellProjects\SimCLRPytorch\new\models\head_trainer.py:33, in HeadTrainer.train(self, train_loader)
#      31 g = torch.Generator()
#      32 g.manual_seed(0)
# ---> 33 for images, labels in tqdm((train_loader)):
#      34     images = torch.cat((images, images), dim=0)
#      35     labels = torch.cat((labels, labels), dim=0)
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\tqdm\std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torch\utils\data\dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torch\utils\data\dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torchvision\datasets\cifar.py:118, in CIFAR10.__getitem__(self, index)
#     115 img = Image.fromarray(img)
#     117 if self.transform is not None:
# --> 118     img = self.transform(img)
#     120 if self.target_transform is not None:
#     121     target = self.target_transform(target)
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torchvision\transforms\transforms.py:135, in ToTensor.__call__(self, pic)
#     127 def __call__(self, pic):
#     128     """
#     129     Args:
#     130         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     133         Tensor: Converted image.
#     134     """
# --> 135     return F.to_tensor(pic)
#
# File ~\DataspellProjects\SimCLRPytorch\venv\lib\site-packages\torchvision\transforms\functional.py:169, in to_tensor(pic)
#     167 img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
#     168 # put it from HWC to CHW format
# --> 169 img = img.permute((2, 0, 1)).contiguous()
#     170 if isinstance(img, torch.ByteTensor):
#     171     return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), 'saved_models/head_training/head_cifar10.pth')
